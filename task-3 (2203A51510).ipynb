# %%
import pandas as pd
d=pd.read_csv('/content/task-3.csv')
print(d)
# Out:
#    S.No.       NAME  Marks
# 0       1  Harshith     78
# 1       2   Srikari     84
# 2       3    Dharma     93
# 3       4  Sathvika     97
# 4       5     Karan     90

# %%
d=pd.read_excel('/content/task-3.xlsx')
print(d)
# Out:
#    S.No.       NAME  Marks
# 0       1  Harshith     78
# 1       2   Srikari     84
# 2       3    Dharma     93
# 3       4  Sathvika     97
# 4       5     Karan     90

# %%
d=pd.read_csv('/content/task-3.tsv')
print(d)
# Out:
#   S.No. \tNAME\tMarks
# 0     1\tHarshith\t78
# 1      2\tSrikari\t84
# 2       3\tDharma\t93
# 3     4\tSathvika\t97
# 4        5\tKaran\t90
